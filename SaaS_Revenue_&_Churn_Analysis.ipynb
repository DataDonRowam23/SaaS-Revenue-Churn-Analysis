# %%
# Load file

subscriptions = pd.read_csv('/var/colab/subscriptions.csv')
monthly_revenue = pd.read_csv('/var/colab/monthly_revenue.csv')

# %%
# Check whether data correctly loaded
subscriptions.head()
# Out:
#   customer_id          plan billing_cycle       industry company_size  seats  \
# 0   CUST-0001  Professional       Monthly         Retail       51-200     64
# 1   CUST-0002  Professional        Annual         Retail       51-200     35
# 2   CUST-0003       Starter        Annual        Finance         500+    266
# 3   CUST-0004      Business        Annual    Real Estate        11-50     34
# 4   CUST-0005       Starter        Annual  Manufacturing       51-200     48
#
#    monthly_revenue acquisition_channel         region signup_date churned  \
# 0           825.55      Organic Search  North America  2022-06-27     Yes
# 1           409.62        Direct Sales  North America  2023-03-19      No
# 2          1004.49             Partner  North America  2024-10-19     Yes
# 3          1006.44             Partner         Europe  2023-01-07      No
# 4           198.43        Direct Sales  North America  2025-09-23      No
#
#    churn_date    churn_reason  support_tickets_12mo  nps_score  \
# 0  2024-03-05  Price Too High                    13          3
# 1         NaN             NaN                     1          3
# 2  2025-04-13  Price Too High                    10          4
# 3         NaN             NaN                     3          7
# 4         NaN             NaN                     3          7
#
#    feature_usage_pct upgraded
# 0                 15       No
# 1                 52      Yes
# 2                 31       No
# 3                 58       No
# 4                 59       No

# %%
monthly_revenue.head()
# Out:
#      month  total_active_customers  new_customers  churned_customers  \
# 0  2022-01                       0              5                  0
# 1  2022-02                       5             10                  1
# 2  2022-03                      14             13                  0
# 3  2022-04                      28             11                  3
# 4  2022-05                      35             11                  1
#
#    monthly_churn_rate_pct  total_mrr  avg_revenue_per_customer  \
# 0                    0.00       0.00                      0.00
# 1                   20.00    7333.07                   1466.61
# 2                    0.00   12301.16                    878.65
# 3                   10.71   24798.76                    885.67
# 4                    2.86   29091.88                    831.20
#
#    customer_acquisition_cost
# 0                     164.92
# 1                     189.21
# 2                     139.49
# 3                     259.09
# 4                     152.96

# %%
# Check dataset shape
print("subscriptions",subscriptions.shape)
print("monthly_revenue",monthly_revenue.shape)
# Out:
# subscriptions (600, 17)
# monthly_revenue (48, 8)

# %%
# Check data type
subscriptions .info()
monthly_revenue .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           600 non-null    object
#  1   plan                  600 non-null    object
#  2   billing_cycle         600 non-null    object
#  3   industry              600 non-null    object
#  4   company_size          600 non-null    object
#  5   seats                 600 non-null    int64
#  6   monthly_revenue       600 non-null    float64
#  7   acquisition_channel   600 non-null    object
#  8   region                600 non-null    object
#  9   signup_date           600 non-null    object
#  10  churned               600 non-null    object
#  11  churn_date            313 non-null    object
#  12  churn_reason          313 non-null    object
#  13  support_tickets_12mo  600 non-null    int64
#  14  nps_score             600 non-null    int64
#  15  feature_usage_pct     600 non-null    int64
#  16  upgraded              600 non-null    object
# dtypes: float64(1), int64(4), object(12)
# memory usage: 79.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      48 non-null     object
#  1   total_active_customers     48 non-null     int64
#  2   new_customers              48 non-null     int64
#  3   churned_customers          48 non-null     int64
#  4   monthly_churn_rate_pct     48 non-null     float64
#  5   total_mrr                  48 non-null     float64
#  6   avg_revenue_per_customer   48 non-null     float64
#  7   customer_acquisition_cost  48 non-null     float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 3.1+ KB

# %%
# Convert date datatype into datetime
subscriptions['signup_date'] = pd.to_datetime(subscriptions["signup_date"])
subscriptions['churn_date'] = pd.to_datetime(subscriptions["churn_date"])
monthly_revenue['churn_date'] = pd.to_datetime(monthly_revenue["month"])

# %%
# Verify the datetype
subscriptions.info()
monthly_revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           600 non-null    object
#  1   plan                  600 non-null    object
#  2   billing_cycle         600 non-null    object
#  3   industry              600 non-null    object
#  4   company_size          600 non-null    object
#  5   seats                 600 non-null    int64
#  6   monthly_revenue       600 non-null    float64
#  7   acquisition_channel   600 non-null    object
#  8   region                600 non-null    object
#  9   signup_date           600 non-null    datetime64[ns]
#  10  churned               600 non-null    object
#  11  churn_date            313 non-null    datetime64[ns]
#  12  churn_reason          313 non-null    object
#  13  support_tickets_12mo  600 non-null    int64
#  14  nps_score             600 non-null    int64
#  15  feature_usage_pct     600 non-null    int64
#  16  upgraded              600 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(10)
# memory usage: 79.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      48 non-null     object
#  1   total_active_customers     48 non-null     int64
#  2   new_customers              48 non-null     int64
#  3   churned_customers          48 non-null     int64
#  4   monthly_churn_rate_pct     48 non-null     float64
#  5   total_mrr                  48 non-null     float64
#  6   avg_revenue_per_customer   48 non-null     float64
#  7   customer_acquisition_cost  48 non-null     float64
#  8   churn_date                 48 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(3), object(1)
# memory usage: 3.5+ KB

# %%
# Check the missing values

subscriptions.isnull().sum()
#Have null vaue in churn date and churn reason [This is compeletly normal because active customer have not churned]
monthly_revenue.isnull().sum()
# Out:
# month                        0
# total_active_customers       0
# new_customers                0
# churned_customers            0
# monthly_churn_rate_pct       0
# total_mrr                    0
# avg_revenue_per_customer     0
# customer_acquisition_cost    0
# churn_date                   0
# dtype: int64

# %%
# Check duplicate values

subscriptions.duplicated().sum()
monthly_revenue.duplicated().sum()  #there is no duplicate value in entire dataset
# Out:
# np.int64(0)

# %%
# Check unique value
subscriptions['plan'].value_counts()
# Out:
# plan
# Starter         217
# Professional    173
# Business        160
# Enterprise       50
# Name: count, dtype: int64

# %%
subscriptions['billing_cycle'].value_counts()
# Out:
# billing_cycle
# Monthly    352
# Annual     248
# Name: count, dtype: int64

# %%
subscriptions['company_size'].value_counts()
# Out:
# company_size
# 11-50      176
# 1-10       157
# 51-200     141
# 201-500     88
# 500+        38
# Name: count, dtype: int64

# %%
subscriptions['acquisition_channel'].value_counts()
# Out:
# acquisition_channel
# Organic Search    153
# Referral          124
# Paid Ads          115
# Partner           100
# Direct Sales       56
# Social Media       52
# Name: count, dtype: int64

# %%
subscriptions.describe()
# Out:
#             seats  monthly_revenue          signup_date  \
# count  600.000000       600.000000                  600
# mean    42.450000       817.654300  2024-01-16 17:48:00
# min      1.000000        24.650000  2022-01-06 00:00:00
# 25%      7.000000       137.137500  2023-01-17 00:00:00
# 50%     26.000000       348.250000  2024-01-18 12:00:00
# 75%     58.000000       874.832500  2025-01-04 12:00:00
# max    297.000000     10978.000000  2025-12-31 00:00:00
# std     51.279823      1352.584783                  NaN
#
#                           churn_date  support_tickets_12mo   nps_score  \
# count                            313            600.000000  600.000000
# mean   2024-06-04 07:35:27.795527168              6.480000    4.365000
# min              2022-02-14 00:00:00              0.000000    1.000000
# 25%              2023-08-24 00:00:00              3.000000    2.000000
# 50%              2024-07-20 00:00:00              6.000000    4.000000
# 75%              2025-04-23 00:00:00             10.000000    6.000000
# max              2025-12-19 00:00:00             15.000000   10.000000
# std                              NaN              4.271613    2.650185
#
#        feature_usage_pct
# count         600.000000
# mean           40.638333
# min            10.000000
# 25%            22.750000
# 50%            36.000000
# 75%            50.000000
# max            95.000000
# std            22.749801

# %%
monthly_revenue.describe()
# Out:
#        total_active_customers  new_customers  churned_customers  \
# count               48.000000      48.000000          48.000000
# mean               167.416667      12.500000           6.520833
# min                  0.000000       5.000000           0.000000
# 25%                104.000000      10.750000           4.000000
# 50%                184.500000      13.000000           7.000000
# 75%                241.750000      14.250000           8.250000
# max                281.000000      19.000000          17.000000
# std                 85.274234       3.339002           3.414547
#
#        monthly_churn_rate_pct      total_mrr  avg_revenue_per_customer  \
# count               48.000000      48.000000                 48.000000
# mean                 4.518958  174888.413958               1010.218958
# min                  0.000000       0.000000                  0.000000
# 25%                  3.007500  102605.177500               1009.865000
# 50%                  3.755000  190681.445000               1030.135000
# 75%                  4.552500  262177.912500               1072.027500
# max                 20.000000  292628.610000               1466.610000
# std                  3.251457   92619.227429                175.723630
#
#        customer_acquisition_cost           churn_date
# count                  48.000000                   48
# mean                  200.040625  2023-12-16 11:00:00
# min                   122.990000  2022-01-01 00:00:00
# 25%                   150.267500  2022-12-24 06:00:00
# 50%                   197.250000  2023-12-16 12:00:00
# 75%                   249.187500  2024-12-08 18:00:00
# max                   279.590000  2025-12-01 00:00:00
# std                    52.694255                  NaN

# %%
# Data quality report
quality_report = pd.DataFrame({
    'Missing_Values' : subscriptions.isnull().sum(),
    'Data_Type' : monthly_revenue.dtypes
})

quality_report
# Out:
#                            Missing_Values       Data_Type
# acquisition_channel                   0.0             NaN
# avg_revenue_per_customer              NaN         float64
# billing_cycle                         0.0             NaN
# churn_date                          287.0  datetime64[ns]
# churn_reason                        287.0             NaN
# churned                               0.0             NaN
# churned_customers                     NaN           int64
# company_size                          0.0             NaN
# customer_acquisition_cost             NaN         float64
# customer_id                           0.0             NaN
# feature_usage_pct                     0.0             NaN
# industry                              0.0             NaN
# month                                 NaN          object
# monthly_churn_rate_pct                NaN         float64
# monthly_revenue                       0.0             NaN
# new_customers                         NaN           int64
# nps_score                             0.0             NaN
# plan                                  0.0             NaN
# region                                0.0             NaN
# seats                                 0.0             NaN
# signup_date                           0.0             NaN
# support_tickets_12mo                  0.0             NaN
# total_active_customers                NaN           int64
# total_mrr                             NaN         float64
# upgraded                              0.0             NaN

# %%
 #Understand the dataset

subscriptions.shape
monthly_revenue.shape
# Out:
# (48, 9)

# %%
# EDA report
# EDA Phase 1: Business Overview
# How many unique customer are using saas product?

subscriptions['customer_id'].unique()
# Out:
# array(['CUST-0001', 'CUST-0002', 'CUST-0003', 'CUST-0004', 'CUST-0005',
#        'CUST-0501', 'CUST-0502', 'CUST-0503', 'CUST-0504', 'CUST-0505',
#        'CUST-0506', 'CUST-0507', 'CUST-0508', 'CUST-0509', 'CUST-0510',
#        'CUST-0511', 'CUST-0512', 'CUST-0513', 'CUST-0514', 'CUST-0515',
#        'CUST-0516', 'CUST-0517', 'CUST-0518', 'CUST-0519', 'CUST-0520',
#        'CUST-0521', 'CUST-0522', 'CUST-0523', 'CUST-0524', 'CUST-0525',
#        'CUST-0526', 'CUST-0527', 'CUST-0528', 'CUST-0529', 'CUST-0530',
#        'CUST-0531', 'CUST-0532', 'CUST-0533', 'CUST-0534', 'CUST-0535',
#        'CUST-0536', 'CUST-0537', 'CUST-0538', 'CUST-0539', 'CUST-0540',
#        'CUST-0541', 'CUST-0542', 'CUST-0543', 'CUST-0544', 'CUST-0545',
#        'CUST-0546', 'CUST-0547', 'CUST-0548', 'CUST-0549', 'CUST-0550',
#        'CUST-0551', 'CUST-0552', 'CUST-0553', 'CUST-0554', 'CUST-0555',
#        'CUST-0556', 'CUST-0557', 'CUST-0558', 'CUST-0559', 'CUST-0560',
#        'CUST-0561', 'CUST-0562', 'CUST-0563', 'CUST-0564', 'CUST-0565',
#        'CUST-0566', 'CUST-0567', 'CUST-0568', 'CUST-0569', 'CUST-0570',
#        'CUST-0571', 'CUST-0572', 'CUST-0573', 'CUST-0574', 'CUST-0575',
#        'CUST-0576', 'CUST-0577', 'CUST-0578', 'CUST-0579', 'CUST-0580',
#        'CUST-0581', 'CUST-0582', 'CUST-0583', 'CUST-0584', 'CUST-0585',
#        'CUST-0586', 'CUST-0587', 'CUST-0588', 'CUST-0589', 'CUST-0590',
#        'CUST-0591', 'CUST-0592', 'CUST-0593', 'CUST-0594', 'CUST-0595',
#        'CUST-0596', 'CUST-0597', 'CUST-0598', 'CUST-0599', 'CUST-0600'],
#       dtype=object)

# %%
# What percentage of customer churned?
subscriptions['churned'].value_counts(normalize=True)*100
# Out:
# churned
# Yes    52.166667
# No     47.833333
# Name: proportion, dtype: float64

# %%
# Whar is the total MRR represented in the customers dataset?
subscriptions['monthly_revenue'].sum()
# Out:
# np.float64(490592.58)

# %%
# Are most customers paying similar amounts, or are these a few large customer driving revenue ?
subscriptions['monthly_revenue'].describe()
# Out:
# count      600.000000
# mean       817.654300
# std       1352.584783
# min         24.650000
# 25%        137.137500
# 50%        348.250000
# 75%        874.832500
# max      10978.000000
# Name: monthly_revenue, dtype: float64

# %%
# Which subscription plan is most popular?
subscriptions['plan'].value_counts()
# Out:
# plan
# Starter         217
# Professional    173
# Business        160
# Enterprise       50
# Name: count, dtype: int64

# %%
# Customer Distribution by plan visualization
subscriptions['plan'].value_counts().plot(kind='bar')
plt.title('Customers by Plan')
plt.show()

# %%
# Which plan generates the most revenue?
subscriptions.groupby('plan')['monthly_revenue'].sum().sort_values(ascending=False)
# Out:
# plan
# Business        208581.83
# Enterprise      149249.65
# Professional     85988.14
# Starter          46772.96
# Name: monthly_revenue, dtype: float64

# %%
# Visualization
subscriptions.groupby('plan')['monthly_revenue'].sum().sort_values(ascending=False).plot(kind='bar')
plt.title('Revenue by plan')
plt.show()

# %%
# Billing Cycle analysis
subscriptions['billing_cycle'].value_counts()
# Out:
# billing_cycle
# Monthly    352
# Annual     248
# Name: count, dtype: int64

# %%
# Do annual customers contribute more revenue than monthly customers?
subscriptions.groupby('billing_cycle')['monthly_revenue'].sum()
# Out:
# billing_cycle
# Annual     183658.53
# Monthly    306934.05
# Name: monthly_revenue, dtype: float64

# %%
# EDA Phase 2: Customer Segmentation Analysis
# Industry analysis
# Which industry generates the highest revenue

subscriptions.groupby('industry')['monthly_revenue'].sum()
# Out:
# industry
# Consulting       47489.04
# Education        58820.37
# Finance          45936.22
# Healthcare       65056.91
# Legal            45126.71
# Manufacturing    56880.71
# Media            42016.19
# Real Estate      44764.08
# Retail           49484.22
# Technology       35018.13
# Name: monthly_revenue, dtype: float64

# %%
# Visulization

subscriptions.groupby('industry')['monthly_revenue'].sum().sort_values(ascending=False).plot(kind='bar')
plt.title('Revenue by industry')
plt.show()

# %%
# Customer distribution by industry
subscriptions['industry'].value_counts()
# Out:
# industry
# Education        77
# Manufacturing    64
# Consulting       62
# Finance          61
# Healthcare       61
# Real Estate      61
# Legal            57
# Media            54
# Retail           52
# Technology       51
# Name: count, dtype: int64

# %%
# Visualization
subscriptions['industry'].value_counts().plot(kind='bar',figsize=(8,5))
plt.title('Customer by industry')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Company Size analysis
# Are enterprise customers driving revenue or are small businesses?
subscriptions['company_size'].value_counts()
# Out:
# company_size
# 11-50      176
# 1-10       157
# 51-200     141
# 201-500     88
# 500+        38
# Name: count, dtype: int64

# %%
# Visualisation
subscriptions.groupby('company_size')['monthly_revenue'].sum().sort_values(ascending = False).plot(kind='bar')
plt.title('Revenue by company_size')
plt.ylabel('Total_Revenue')
plt.show()

# %%
# Region Analysis
# Which region contribute the monthly_revenue
subscriptions['region'].value_counts()
# Out:
# region
# North America    284
# Europe           162
# Asia Pacific      94
# Latin America     60
# Name: count, dtype: int64

# %%
# Visualization
subscriptions.groupby('region')['monthly_revenue'].sum().sort_values(ascending=False).plot(kind='bar')
plt.title('Revenue by Region')
plt.ylabel('Total_Revenue')
plt.show()

# %%
# Acquisition Channel Analysis
# Which acquisition channel bring the highest revenue customers?

subscriptions['acquisition_channel'].value_counts()
# Out:
# acquisition_channel
# Organic Search    153
# Referral          124
# Paid Ads          115
# Partner           100
# Direct Sales       56
# Social Media       52
# Name: count, dtype: int64

# %%
# Visualization
subscriptions.groupby('acquisition_channel')['monthly_revenue'].sum().sort_values(ascending=False).plot(kind='bar')
plt.title('Revenue By Acquisition_Channel')
plt.ylabel('Total_Revenue')
plt.show()

# %%
# Seats Analysis
# Do customer with more seats genrate more revenue?
subscriptions['seats'].describe()
# Out:
# count    600.000000
# mean      42.450000
# std       51.279823
# min        1.000000
# 25%        7.000000
# 50%       26.000000
# 75%       58.000000
# max      297.000000
# Name: seats, dtype: float64

# %%
plt.figure(figsize =(8,5))

plt.scatter(subscriptions['seats'],subscriptions['monthly_revenue'])
plt.title('Seats VS Revenue')
plt.xlabel('Seats')
plt.ylabel('Total_Revenue')
plt.show()

# %%
# Are customer actively using the product?
subscriptions['feature_usage_pct'].describe()
# Out:
# count    600.000000
# mean      40.638333
# std       22.749801
# min       10.000000
# 25%       22.750000
# 50%       36.000000
# 75%       50.000000
# max       95.000000
# Name: feature_usage_pct, dtype: float64

# %%
subscriptions['feature_usage_pct'].hist(bins=20)
plt.title('Feature_Usage_Distribution')
plt.xlabel('Usage%')
plt.show()

# %%
# EDA Phase 3 : Churn Analysis
# Overall churn rate

subscriptions['churned'].value_counts()
# Out:
# churned
# Yes    313
# No     287
# Name: count, dtype: int64

# %%
churn_rate = subscriptions['churned'].value_counts(normalize=True)['Yes']*100
print(f"churn_rate:{churn_rate:.2f}%")
# Out:
# churn_rate:52.17%

# %%
# Churn by plan

churn_plan = pd.crosstab(subscriptions['plan'],subscriptions['churned'],normalize = 'index')*100
churn_plan
# Out:
# churned              No        Yes
# plan
# Business      58.750000  41.250000
# Enterprise    78.000000  22.000000
# Professional  52.023121  47.976879
# Starter       29.493088  70.506912

# %%
churn_plan.plot(kind='bar',figsize=(8,5))
plt.title('Churn Rate by Plan')
plt.ylabel('Percentage')
plt.show()

# The starter plan has the highest churn rate, indicating customers on this tier may not be receiving enough value.

# %%
# Churn by billing cycle
# Do annual customer churn less than monthly customers?
churn_billing_cycle = pd.crosstab(subscriptions['plan'],subscriptions['billing_cycle'],normalize = 'index')*100
churn_billing_cycle
# Out:
# billing_cycle     Annual    Monthly
# plan
# Business       45.625000  54.375000
# Enterprise     36.000000  64.000000
# Professional   42.774566  57.225434
# Starter        38.248848  61.751152

# %%
churn_billing_cycle.plot(kind='bar',figsize=(8,5))
plt.title('Churn By Billing Cycle')
plt.ylabel('Percentage')
plt.show()

# Annual subscribers show lower churn because they are more committed

# %%
# Churn by industry
# Which industry have the highest churn?
industry_churn = pd.crosstab(subscriptions['plan'],subscriptions['industry'],normalize = 'index')*100

# %%
# Visualization
industry_churn.plot(kind='bar',figsize = (20,8))
plt.title('Churn Rate By Industry')
plt.show()

# %%
# Churn by company size
# Do small companies churn more than large companies?
Company_churn = pd.crosstab(subscriptions['plan'],subscriptions['company_size'],normalize = 'index')*100

# %%
# Visualization
Company_churn.plot(kind='bar',figsize=(20,8))
plt.title('Churn Rate by Company_Size')
plt.show()

# Small companies churn more frequently than enterprise customers.

# %%
# NPS VS CHURN

def nps_group(x):
    if x>=9:
        return 'Promoter'
    elif x>=7:
        return 'Passive'
    else:
        return 'Detractor'
subscriptions['nps_category']= subscriptions['nps_score'].apply(nps_group)

# %%
subscriptions['nps_category'].value_counts()
# Out:
# nps_category
# Detractor    470
# Passive       69
# Promoter      61
# Name: count, dtype: int64

# %%
Churn_nps_category = pd.crosstab(subscriptions['nps_category'],subscriptions['churned'],normalize = 'index')*100

# %%
# Visualization
Churn_nps_category.plot(kind='bar',figsize = (20,8))
plt.title('Churn by Nps_Category')
plt.ylabel('Percentage')
plt.show()

# Detractors churn significantly more than Promoters and Passive.

# %%
# Feature Usage vs Churn
# Does low product usage lead to churn?

subscriptions['usage_group'] = pd.cut(subscriptions['feature_usage_pct'],bins=[0,40,70,100],labels=['Low','Medium','High'])

# %%
subscriptions['usage_group'].value_counts()
# Out:
# usage_group
# Low       358
# Medium    151
# High       91
# Name: count, dtype: int64

# %%
Churn_usage_group = pd.crosstab(subscriptions['usage_group'],subscriptions['churned'],normalize = 'index')*100

# %%
Churn_usage_group.plot(kind='bar',figsize = (20,8))
plt.title('Churn By Usage Group')
plt.ylabel('Percentage')
plt.show()

# Customer with low products usage exhibit significantly higher churn rates than highly engaged users.

# %%
# Support ticket vs churn
# Do customers with many support issues churn rate?

subscriptions.groupby('churned')['support_tickets_12mo'].mean()
# Out:
# churned
# No     5.501742
# Yes    7.376997
# Name: support_tickets_12mo, dtype: float64

# %%
# Visualization
subscriptions.boxplot(column = 'support_tickets_12mo',by = 'churned', figsize = (20,8))
plt.title('Support Tickets by churn status')
plt.show()

# Churned customers submitted more support tickets on average, suggesting product fiction may contribute to customer loss.

# %%
# Churned Reasons
churned_customer = subscriptions[subscriptions['churned'] == 'Yes']
churned_customer['churn_reason'].value_counts()
# Out:
# churn_reason
# Budget Cuts            53
# Price Too High         51
# Company Closed         48
# Poor Support           42
# No Longer Needed       41
# Missing Features       40
# Switched Competitor    38
# Name: count, dtype: int64

# %%
# Visualizations

churned_customer['churn_reason'].value_counts().plot(kind='bar',figsize = (20,8))
plt.title('Top churn reason')
plt.show()

# %%
# Phase 4: Revenue & Growth Analysis
monthly_revenue.head()
# Out:
#      month  total_active_customers  new_customers  churned_customers  \
# 0  2022-01                       0              5                  0
# 1  2022-02                       5             10                  1
# 2  2022-03                      14             13                  0
# 3  2022-04                      28             11                  3
# 4  2022-05                      35             11                  1
#
#    monthly_churn_rate_pct  total_mrr  avg_revenue_per_customer  \
# 0                    0.00       0.00                      0.00
# 1                   20.00    7333.07                   1466.61
# 2                    0.00   12301.16                    878.65
# 3                   10.71   24798.76                    885.67
# 4                    2.86   29091.88                    831.20
#
#    customer_acquisition_cost churn_date
# 0                     164.92 2022-01-01
# 1                     189.21 2022-02-01
# 2                     139.49 2022-03-01
# 3                     259.09 2022-04-01
# 4                     152.96 2022-05-01

# %%
monthly_revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      48 non-null     object
#  1   total_active_customers     48 non-null     int64
#  2   new_customers              48 non-null     int64
#  3   churned_customers          48 non-null     int64
#  4   monthly_churn_rate_pct     48 non-null     float64
#  5   total_mrr                  48 non-null     float64
#  6   avg_revenue_per_customer   48 non-null     float64
#  7   customer_acquisition_cost  48 non-null     float64
#  8   churn_date                 48 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(3), object(1)
# memory usage: 3.5+ KB

# %%
monthly_revenue.describe()
# Out:
#        total_active_customers  new_customers  churned_customers  \
# count               48.000000      48.000000          48.000000
# mean               167.416667      12.500000           6.520833
# min                  0.000000       5.000000           0.000000
# 25%                104.000000      10.750000           4.000000
# 50%                184.500000      13.000000           7.000000
# 75%                241.750000      14.250000           8.250000
# max                281.000000      19.000000          17.000000
# std                 85.274234       3.339002           3.414547
#
#        monthly_churn_rate_pct      total_mrr  avg_revenue_per_customer  \
# count               48.000000      48.000000                 48.000000
# mean                 4.518958  174888.413958               1010.218958
# min                  0.000000       0.000000                  0.000000
# 25%                  3.007500  102605.177500               1009.865000
# 50%                  3.755000  190681.445000               1030.135000
# 75%                  4.552500  262177.912500               1072.027500
# max                 20.000000  292628.610000               1466.610000
# std                  3.251457   92619.227429                175.723630
#
#        customer_acquisition_cost           churn_date
# count                  48.000000                   48
# mean                  200.040625  2023-12-16 11:00:00
# min                   122.990000  2022-01-01 00:00:00
# 25%                   150.267500  2022-12-24 06:00:00
# 50%                   197.250000  2023-12-16 12:00:00
# 75%                   249.187500  2024-12-08 18:00:00
# max                   279.590000  2025-12-01 00:00:00
# std                    52.694255                  NaN

# %%
# MRR GROWTH
# How has monthly recurring revenue changed over time?
monthly_revenue[['month','total_mrr']]
# Out:
#       month  total_mrr
# 0   2022-01       0.00
# 1   2022-02    7333.07
# 2   2022-03   12301.16
# 3   2022-04   24798.76
# 4   2022-05   29091.88
# 5   2022-06   38919.93
# 6   2022-07   45097.72
# 7   2022-08   54140.41
# 8   2022-09   65198.00
# 9   2022-10   86824.16
# 10  2022-11   93168.11
# 11  2022-12   96100.66
# 12  2023-01  104773.35
# 13  2023-02  115539.13
# 14  2023-03  125258.61
# 15  2023-04  129471.28
# 16  2023-05  142401.69
# 17  2023-06  142966.32
# 18  2023-07  147630.36
# 19  2023-08  158920.70
# 20  2023-09  162830.02
# 21  2023-10  170763.72
# 22  2023-11  184058.29
# 23  2023-12  189579.35
# 24  2024-01  191783.54
# 25  2024-02  192379.41
# 26  2024-03  196219.33
# 27  2024-04  200076.61
# 28  2024-05  217117.58
# 29  2024-06  215810.52
# 30  2024-07  222303.36
# 31  2024-08  242222.62
# 32  2024-09  234749.84
# 33  2024-10  239344.73
# 34  2024-11  253489.47
# 35  2024-12  260856.24
# 36  2025-01  266142.93
# 37  2025-02  274162.54
# 38  2025-03  280928.08
# 39  2025-04  287791.15
# 40  2025-05  287207.82
# 41  2025-06  280683.13
# 42  2025-07  287661.73
# 43  2025-08  287743.00
# 44  2025-09  290824.44
# 45  2025-10  280089.15
# 46  2025-11  285261.36
# 47  2025-12  292628.61

# %%
plt.figure(figsize=(20,8))
plt.plot(monthly_revenue['month'],monthly_revenue['total_mrr'])
plt.title('Monthly Recurring Revenue Trend')
plt.xlabel('Month')
plt.ylabel('MRR')
plt.show()

# Healthy Growth in MRR

# %%
# Customers growth trend
plt.figure(figsize = (20,8))

plt.plot(monthly_revenue['month'], monthly_revenue['total_active_customers'])
plt.title('Active Customer Growth')
plt.xlabel('Month')
plt.ylabel('Customers')
plt.show()

# Healthy active customer growth over the period

# %%
# New Customer VS Churned Customer
# Are we acquiring customers faster than we are losing them?

plt.figure(figsize = (20,8))

plt.plot(monthly_revenue['month'],monthly_revenue['new_customers'],label = 'New Customers')
plt.plot(monthly_revenue['month'],monthly_revenue['churned_customers'],label = 'Churned Customers')
plt.legend()
plt.title('Customer Acquisition VS Churn')
plt.xlabel('Month')
plt.show()

# %%
# Monthly Churn rate trend
# Is churn improving or worsening over time
plt.figure(figsize = (20,8))

plt.plot(monthly_revenue['month'],monthly_revenue['monthly_churn_rate_pct'])
plt.title('Monthly Churn Rate Trend')
plt.xlabel('Month')
plt.ylabel('Churn Rate %')
plt.show()

# %%
# Average revenue per customer trend
plt.figure(figsize = (20,8))

plt.plot(monthly_revenue['month'],monthly_revenue['avg_revenue_per_customer'])
plt.title('Average Revenue Customer Trend')
plt.xlabel('Month')
plt.ylabel('Customers')
plt.show()

# %%
# Customer Aquisition Cost (CAC)
# Is it becoming more expensive to acuire customers?

plt.figure(figsize = (20,8))

plt.plot(monthly_revenue['month'],monthly_revenue['customer_acquisition_cost'])
plt.title('Customer Acquisition Cost Trend')
plt.xlabel('Month')
plt.ylabel('Customers')
plt.show()

# %%
# Revenue Growth %
# Which month experienced the strongest growth?

monthly_revenue['mrr_growth_pct'] = (monthly_revenue['total_mrr'].pct_change()*100)

# %%
monthly_revenue[['month','total_mrr','mrr_growth_pct']]
# Out:
#       month  total_mrr  mrr_growth_pct
# 0   2022-01       0.00             NaN
# 1   2022-02    7333.07             inf
# 2   2022-03   12301.16       67.749115
# 3   2022-04   24798.76      101.596923
# 4   2022-05   29091.88       17.311833
# 5   2022-06   38919.93       33.782794
# 6   2022-07   45097.72       15.873076
# 7   2022-08   54140.41       20.051324
# 8   2022-09   65198.00       20.423913
# 9   2022-10   86824.16       33.169975
# 10  2022-11   93168.11        7.306664
# 11  2022-12   96100.66        3.147590
# 12  2023-01  104773.35        9.024589
# 13  2023-02  115539.13       10.275304
# 14  2023-03  125258.61        8.412284
# 15  2023-04  129471.28        3.363178
# 16  2023-05  142401.69        9.987087
# 17  2023-06  142966.32        0.396505
# 18  2023-07  147630.36        3.262335
# 19  2023-08  158920.70        7.647709
# 20  2023-09  162830.02        2.459919
# 21  2023-10  170763.72        4.872382
# 22  2023-11  184058.29        7.785360
# 23  2023-12  189579.35        2.999626
# 24  2024-01  191783.54        1.162674
# 25  2024-02  192379.41        0.310699
# 26  2024-03  196219.33        1.996014
# 27  2024-04  200076.61        1.965800
# 28  2024-05  217117.58        8.517222
# 29  2024-06  215810.52       -0.602006
# 30  2024-07  222303.36        3.008584
# 31  2024-08  242222.62        8.960395
# 32  2024-09  234749.84       -3.085088
# 33  2024-10  239344.73        1.957356
# 34  2024-11  253489.47        5.909777
# 35  2024-12  260856.24        2.906144
# 36  2025-01  266142.93        2.026668
# 37  2025-02  274162.54        3.013272
# 38  2025-03  280928.08        2.467711
# 39  2025-04  287791.15        2.442999
# 40  2025-05  287207.82       -0.202692
# 41  2025-06  280683.13       -2.271766
# 42  2025-07  287661.73        2.486291
# 43  2025-08  287743.00        0.028252
# 44  2025-09  290824.44        1.070900
# 45  2025-10  280089.15       -3.691330
# 46  2025-11  285261.36        1.846630
# 47  2025-12  292628.61        2.582632

# %%
# Visualization

plt.figure(figsize = (20,8))

plt.plot(monthly_revenue['month'],monthly_revenue['mrr_growth_pct'])
plt.axhline(0)
plt.title('MRR Growth Rate')
plt.show()

# %%
# Net customer growth
# is the business gaining or lossing customers overall?
monthly_revenue['net_customer_growth'] = monthly_revenue['new_customers']-monthly_revenue['churned_customers']

# %%
monthly_revenue[['month','net_customer_growth']]
# Out:
#       month  net_customer_growth
# 0   2022-01                    5
# 1   2022-02                    9
# 2   2022-03                   13
# 3   2022-04                    8
# 4   2022-05                   10
# 5   2022-06                    8
# 6   2022-07                    2
# 7   2022-08                   12
# 8   2022-09                    8
# 9   2022-10                   11
# 10  2022-11                    9
# 11  2022-12                   12
# 12  2023-01                    8
# 13  2023-02                    7
# 14  2023-03                    3
# 15  2023-04                    6
# 16  2023-05                    9
# 17  2023-06                    5
# 18  2023-07                   12
# 19  2023-08                    3
# 20  2023-09                   10
# 21  2023-10                   11
# 22  2023-11                    3
# 23  2023-12                    2
# 24  2024-01                    3
# 25  2024-02                   -1
# 26  2024-03                   15
# 27  2024-04                    3
# 28  2024-05                    6
# 29  2024-06                    4
# 30  2024-07                    6
# 31  2024-08                    5
# 32  2024-09                    4
# 33  2024-10                    6
# 34  2024-11                    3
# 35  2024-12                    6
# 36  2025-01                    4
# 37  2025-02                    7
# 38  2025-03                   11
# 39  2025-04                   -4
# 40  2025-05                   -3
# 41  2025-06                    4
# 42  2025-07                    0
# 43  2025-08                    0
# 44  2025-09                    4
# 45  2025-10                    9
# 46  2025-11                    2
# 47  2025-12                    7

# %%
plt.figure(figsize = (20,8))

plt.plot(monthly_revenue['month'],monthly_revenue['net_customer_growth'])
plt.axhline(0)
plt.title('Net Customer Growth')
plt.ylabel('Customers')
plt.xlabel('Month')
plt.show()

# %%
print("Latest MRR:", monthly_revenue['total_mrr'].iloc[-1])
print("Latest Customers:", monthly_revenue['total_active_customers'].iloc[-1])
print("Latest Churn Rate:", monthly_revenue['monthly_churn_rate_pct'].iloc[-1])
print("Latest ARPU:", monthly_revenue['avg_revenue_per_customer'].iloc[-1])
print("Latest CAC:", monthly_revenue['customer_acquisition_cost'].iloc[-1])
# Out:
# Latest MRR: 292628.61
# Latest Customers: 281
# Latest Churn Rate: 1.42
# Latest ARPU: 1041.38
# Latest CAC: 151.47

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.12-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (2.0.51)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (3.5.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (4.16.0)
# Downloading psycopg2_binary-2.9.12-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 52.6 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.12

# %%
from sqlalchemy import create_engine

# Step1 Connect to postgreSQL
# Replace placeholders with your actual details

#username = "Postgres"   #default users
#password = "@Donrowam2024"  #the password you set during installation
#host = "localhost"        #if running locally
#port = "5432"             #default postgresql port
#database = "SaaS_Analysis"  #the database you created in pgadmin

#engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

#step2 load dataframe into postgreSql
#choose any table name

#subscriptions.to_sql(name = "subscriptions", con=engine, if_exists = "replace",index=False)
#monthly_revenue.to_sql(name = "monthly_revenue", con=engine, if_exists = "replace",index=False)

#print("All tables loaded successfully!")

# %%
from IPython.display import FileLink

# Save the file
subscriptions.to_csv('subscriptions_df.csv', index=False)
monthly_revenue.to_csv('monthly_revenue_df.csv', index=False)

# Create clickable download link
display(FileLink('subscriptions_df.csv'))
display(FileLink('monthly_revenue_df.csv'))
# Out:
# /content/subscriptions_df.csv
# /content/monthly_revenue_df.csv
